# %%
from abc import ABC, abstractmethod
from flair.embeddings import ELMoEmbeddings, FlairEmbeddings, DocumentPoolEmbeddings, Sentence
from gensim.models import KeyedVectors

import csv
import flair
import fasttext
import torch

# Use CPU if GPU is not available
flair.device = torch.device('cpu')

# %%
ELMO_MODEL_W = './embeddings/elmo/bioreddit.hdf5'
ELMO_MODEL_O = './embeddings/elmo/options.json'
GLOVE_MODEL = './embeddings/glove/bioreddit.200.gensim'
FASTTEXT_MODEL = './embeddings/fasttext/reddit-biomed.bin'
FLAIR_MODEL_F =  './embeddings/flair/forward.pt'
FLAIR_MODEL_B = './embeddings/flair/backward.pt'

# %%
# Generic class to represent a model
class ModelLoader(ABC):

    def __init__(self,model_name):
        self.model_name = model_name
        self.model = None
        
    @abstractmethod
    def load_model(self, model_path):
        pass
    
    @abstractmethod
    def get_vector(self, text):
        pass

# %%
class FastTextEmbedder(ModelLoader):
    
    def __init__(self):
        super().__init__('fasttext')
        
    def load_model(self,model_path):
        self.model = fasttext.load_model(model_path)
        
    def get_vector(self,text):
        return self.model[text]

# %%
class GloVeEmbedder(ModelLoader):
    
    def __init__(self):
        super().__init__('glove')
        
    def load_model(self,model_path):
        self.model = KeyedVectors.load(model_path,mmap='r')

        
    def get_vector(self,text):
        return self.model[text]

# %%
class FlairEmbedder(ModelLoader):
    def __init__(self):
        super().__init__('flair')

    def load_model(self, model_path):
        flair_embedding_forward = FlairEmbeddings(model_path[0])
        flair_embedding_backward = FlairEmbeddings(model_path[1])

        self.model = DocumentPoolEmbeddings(
            [flair_embedding_backward, flair_embedding_forward])

    def get_vector(self, text):
        s = Sentence(text)
        self.model.embed(s)
        return s.get_embedding()

# %%
class ELMoEmbedder(ModelLoader):
    def __init__(self):
        super().__init__('flair')

    def load_model(self, model_path):
        elmo_embeddings = ELMoEmbeddings(weight_file=model_path[0],
                                    options_file=model_path[1])
        
        self.model = DocumentPoolEmbeddings(
            [elmo_embeddings])

    def get_vector(self, text):
        s = Sentence(text)
        self.model.embed(s)
        return s.get_embedding()

# %%
models = [(FastTextEmbedder, FASTTEXT_MODEL), 
          (GloVeEmbedder, GLOVE_MODEL),
          (FlairEmbedder, [
              FLAIR_MODEL_F,
              FLAIR_MODEL_B,
          ]),
         (ELMoEmbedder, [
              ELMO_MODEL_W,
              ELMO_MODEL_O,
          ])]

# %%
for model_type, model_path in models:
    model = model_type()
    model.load_model(model_path)
    print(model.model_name, end='\n***\n')
    print(model.get_vector('cancer')[:5])
# Out:
# fasttext
# ***
# [-0.30783233 -0.21036296 -0.12321309  0.07858984 -0.16739686]
# glove
# ***
# [-0.772139  0.560792  0.598145 -0.912497  0.001729]
# flair
# ***
# tensor([ 0.2916, -0.0142,  0.0019, -0.1679,  0.2879], grad_fn=<SliceBackward>)
# flair
# ***
# tensor([-0.0947, -0.0650, -0.8767, -0.0830, -0.4786], grad_fn=<SliceBackward>)

# %%
# Example: Elmo embeddings

elmo = ELMoEmbedder()
elmo.load_model([ELMO_MODEL_W, ELMO_MODEL_O])

with open('./snomed_mappings.tsv') as tsvfile:
    reader = csv.reader(tsvfile, delimiter='\t')
    for row in list(reader)[:50]: # print the first 50 rows only
        print(row[0])
        print(model.get_vector(row[0]))
# Out:
# 11-beta-hydroxylase deficiency
# tensor([-0.2940, -0.5838, -0.0213,  ..., -0.1921, -0.1590,  0.4487],
#        grad_fn=<CatBackward>)
# 11β-OHD
# tensor([-1.2703, -0.3492,  0.2137,  ..., -0.1244, -0.8361,  0.4300],
#        grad_fn=<CatBackward>)
# 1°HPT
# tensor([-1.4337, -0.4270,  0.1452,  ..., -0.0409, -1.0152,  0.4035],
#        grad_fn=<CatBackward>)
# 21-hydroxylase deficiency
# tensor([-0.1441, -0.4978, -0.0346,  ..., -0.2250, -0.3382,  0.4941],
#        grad_fn=<CatBackward>)
# 21-hydroxylase deficiency
# tensor([-0.1441, -0.4978, -0.0346,  ..., -0.2934, -0.3345,  0.4075],
#        grad_fn=<CatBackward>)
# 21-OHD
# tensor([-9.7342e-01, -4.6498e-01,  1.7340e-01,  ...,  2.0582e-02,
#         -3.4103e-01,  4.1576e-04], grad_fn=<CatBackward>)
# 21-OHD
# tensor([-0.9734, -0.4650,  0.1734,  ...,  0.0499, -0.3469, -0.0108],
#        grad_fn=<CatBackward>)
# A1ATD
# tensor([-0.8987, -0.4080,  0.3829,  ..., -0.0452,  0.2464,  0.2301],
#        grad_fn=<CatBackward>)
# AA amyloidosis
# tensor([ 0.2633, -0.3631, -0.8415,  ...,  0.3193,  0.1832,  0.4211],
#        grad_fn=<CatBackward>)
# AA
# tensor([-0.0590,  0.0080, -0.8354,  ...,  0.3355,  0.6360, -0.1024],
#        grad_fn=<CatBackward>)
# AATD
# tensor([-0.2761,  0.0312, -0.0877,  ...,  0.5818,  0.7322, -0.2183],
#        grad_fn=<CatBackward>)
# abdominal adhesions
# tensor([-0.5131,  0.1820, -1.1597,  ..., -0.5729, -0.3712, -0.3240],
#        grad_fn=<CatBackward>)
# abdominal, chest, and joint pain
# tensor([-0.3407, -0.1668, -0.4345,  ...,  0.0317,  0.4041,  0.2866],
#        grad_fn=<CatBackward>)
# abdominal discomfort/pain
# tensor([-0.1752, -0.6209, -0.4585,  ..., -0.3400,  0.3334,  0.2531],
#        grad_fn=<CatBackward>)
# abdominal discomfort
# tensor([-0.0998, -0.7898, -0.8242,  ...,  0.1630,  1.0634,  0.0922],
#        grad_fn=<CatBackward>)
# abdominal pain
# tensor([-0.3412, -0.2222, -0.4008,  ..., -0.1321,  0.8692,  0.3358],
#        grad_fn=<CatBackward>)
# Abdominal pain
# tensor([-3.1533e-01,  1.2925e-02, -4.0921e-01,  ..., -6.0222e-04,
#          8.4858e-01,  5.4864e-01], grad_fn=<CatBackward>)
# abdominal symptoms
# tensor([-0.2803, -0.2431, -0.3429,  ..., -0.2697,  1.2723,  0.6414],
#        grad_fn=<CatBackward>)
# abdominal, thoracic or joint pain
# tensor([-0.0071, -0.0692, -0.3927,  ..., -0.1121,  0.1309,  0.8549],
#        grad_fn=<CatBackward>)
# abdominal wall abnormality
# tensor([-0.0896,  0.2589, -0.4064,  ..., -0.3586,  1.1071,  0.8687],
#        grad_fn=<CatBackward>)
# aberrant course of the facial nerve
# tensor([-0.1316,  0.1707, -0.4953,  ..., -0.1278,  0.0327,  0.7223],
#        grad_fn=<CatBackward>)
# aberrant food uptake
# tensor([-0.2657, -0.9327, -0.1928,  ...,  0.0761, -0.1892,  0.7838],
#        grad_fn=<CatBackward>)
# aberrations of the nervous system
# tensor([-0.2233,  0.0206, -0.1985,  ..., -0.6343, -0.0398, -0.0353],
#        grad_fn=<CatBackward>)
# abetalipoproteinemia
# tensor([ 0.0936, -1.0907,  0.8149,  ...,  0.7261,  0.1290,  0.6360],
#        grad_fn=<CatBackward>)
# abnormal accumulation of iron
# tensor([ 0.1871, -0.2288,  0.0866,  ...,  0.0547, -0.4838,  0.8027],
#        grad_fn=<CatBackward>)
# abnormal appearing mitochondria
# tensor([0.3933, 0.0456, 0.0448,  ..., 0.2466, 0.5741, 0.3356],
#        grad_fn=<CatBackward>)
# abnormal bleeding
# tensor([ 0.2842, -0.5380, -0.0898,  ...,  0.2163,  0.7862, -0.0879],
#        grad_fn=<CatBackward>)
# abnormal blinking
# tensor([ 0.1192,  0.4636,  0.2500,  ...,  0.9669, -0.0471, -0.2388],
#        grad_fn=<CatBackward>)
# abnormal bone joints
# tensor([-0.0856,  0.1342, -0.4601,  ..., -0.0783,  0.2366,  0.3146],
#        grad_fn=<CatBackward>)
# abnormal coagulation
# tensor([ 0.2480,  0.1971, -0.3363,  ..., -0.0420,  0.2322,  1.4896],
#        grad_fn=<CatBackward>)
# abnormal craniofacial contour
# tensor([ 0.6295,  0.1554, -0.8711,  ...,  0.4298,  0.5343,  1.3495],
#        grad_fn=<CatBackward>)
# abnormal creases on the hands and feet
# tensor([ 0.2524, -0.1328, -0.2948,  ...,  0.0175,  0.0204,  0.7819],
#        grad_fn=<CatBackward>)
# abnormal dentition
# tensor([ 0.0827,  0.0121, -0.5741,  ...,  0.3250,  0.9247,  0.1181],
#        grad_fn=<CatBackward>)
# abnormal development of eccrine sweat glands, teeth, and hair
# tensor([-0.0821, -0.2780, -0.2289,  ...,  0.0989,  0.2558,  0.2889],
#        grad_fn=<CatBackward>)
# abnormal development of the abducent nerve
# tensor([-0.1460,  0.0061, -0.0117,  ...,  0.1904,  0.2066,  0.7201],
#        grad_fn=<CatBackward>)
# abnormal development
# tensor([-0.0114, -0.4815, -0.0771,  ..., -0.2149,  0.4210,  0.3273],
#        grad_fn=<CatBackward>)
# abnormal EEG patterns
# tensor([-0.1353, -0.3803,  0.1150,  ..., -0.8624, -0.2765,  0.7648],
#        grad_fn=<CatBackward>)
# abnormal erythrocyte morphology
# tensor([-0.2817, -0.2267, -0.0878,  ..., -0.7186,  1.0434,  1.4338],
#        grad_fn=<CatBackward>)
# abnormal facies
# tensor([ 0.0927, -0.1117, -0.3647,  ...,  0.0614,  0.0376,  0.0119],
#        grad_fn=<CatBackward>)
# abnormal form of hemoglobin
# tensor([ 0.2057, -0.1673, -0.5198,  ..., -0.8726, -0.3761,  0.8255],
#        grad_fn=<CatBackward>)
# abnormal gait
# tensor([ 0.4712,  0.4052, -0.8011,  ...,  0.6747,  0.9089,  0.5177],
#        grad_fn=<CatBackward>)
# abnormal growth of hyalinized fibrous tissues
# tensor([-0.0489, -0.4882, -0.1312,  ..., -0.1390, -0.7688,  0.5635],
#        grad_fn=<CatBackward>)
# abnormal hair
# tensor([-0.3913,  0.2106, -0.4283,  ...,  0.3414,  0.8799, -0.1000],
#        grad_fn=<CatBackward>)
# abnormal Hb
# tensor([-0.1247, -0.2981, -0.4132,  ...,  0.2372, -0.1123,  0.6675],
#        grad_fn=<CatBackward>)
# abnormal hemoglobin S
# tensor([ 0.2676, -0.0803, -0.2820,  ..., -0.1592, -0.6927,  0.4400],
#        grad_fn=<CatBackward>)
# abnormalities (including bone, brain, cancer, dental, eye, gastrointestinal, immunological and lung)
# tensor([-0.0773, -0.1889, -0.4322,  ...,  0.1788, -0.1507,  1.3380],
#        grad_fn=<CatBackward>)
# abnormalities in neuronal migration or differentiation
# tensor([ 0.2094, -0.3219,  0.1002,  ..., -0.2726,  0.2570,  1.2361],
#        grad_fn=<CatBackward>)
# abnormalities in the cardiovascular, skeletal, and ocular systems
# tensor([-0.0417,  0.0052, -0.2793,  ..., -0.4783, -0.1171,  0.7757],
#        grad_fn=<CatBackward>)
# abnormalities of eye movements
# tensor([ 0.0719,  0.2711,  0.0910,  ..., -0.5039, -0.3359, -0.1280],
#        grad_fn=<CatBackward>)
# abnormalities of the choriocapillaris or the RPE
# tensor([ 0.0194,  0.1418, -0.0324,  ...,  0.1142, -0.4202,  0.2345],
#        grad_fn=<CatBackward>)
